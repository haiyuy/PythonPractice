# %%
str1 = "Hello"
str2 = "Python"
greeting = str1 + " " + str2
length = len(greeting)
print(f'拼接结果: {greeting}')
print(f'字符串长度: {length}')
print(f'第一个字符: {greeting[0]}')
print(f'第二个字符: {greeting[1]}')
print(f'最后一个字符: {greeting[-1]}')
# Out:
# 拼接结果: Hello Python
# 字符串长度: 12
# 第一个字符: H
# 第二个字符: e
# 最后一个字符: n

# %%
text = "PythonProgramming"
part1 = text[:6]
part2 = text[-11:]
middle = text[5:10]
print(f'前6个字符: {part1}')
print(f'后11个字符: {part2}')
print(f'中间5个字符: {middle}')
print(f'part1和part2的总长度: {len(part1 + part2)}')
# Out:
# 前6个字符: Python
# 后11个字符: Programming
# 中间5个字符: nProg
# part1和part2的总长度: 17

# %%
age_str = "25"
height_str = "1.75"
score = 95
age = int(age_str)
height = float(height_str)
score_str = str(score)
total = age + score
print(f'年龄(整数): {age}, 类型: {type(age)}')
print(f'身高(浮点数): {height}, 类型: {type(height)}')
print(f'分数(字符串): {score_str}, 类型: {type(score_str)}')
print(f'年龄+分数: {total}')
# Out:
# 年龄(整数): 25, 类型: <class 'int'>
# 身高(浮点数): 1.75, 类型: <class 'float'>
# 分数(字符串): 95, 类型: <class 'str'>
# 年龄+分数: 120

# %%
password = "python123"
min_length = 8
is_valid_length = len(password) >= min_length
first_char = password[0]
last_char = password[-1]
first_six_chars = password[:6]
is_python = first_six_chars == "python"
print(f'密码: {password}')
print(f'密码长度: {len(password)}')
print(f'长度符合要求(>=8): {is_valid_length}')
print(f'首字符: {first_char}, 尾字符: {last_char}')
print(f'前6个字符: {first_six_chars}')
print(f"前6个字符是否为'python': {is_python}")
# Out:
# 密码: python123
# 密码长度: 9
# 长度符合要求(>=8): True
# 首字符: p, 尾字符: 3
# 前6个字符: python
# 前6个字符是否为'python': True
