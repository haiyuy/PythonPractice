# %%
a,b,c=1,2,3
print(a)
print(b)
print(c)
# Out:
# 1
# 2
# 3

# %%
print(a,b,c,sep='\n')
# Out:
# 1
# 2
# 3

# %%
name="小明"
city="北京"
print(f'我是{name}，家住{city}')
# Out:
# 我是小明，家住北京

# %%
name="小明"
city="北京"
print(f'我是"{name}"，家住{city}')
# Out:
# 我是"小明"，家住北京

# %%
print(f'我是{name}，\n家住{city}')
# Out:
# 我是小明，
# 家住北京

# %%
num1=20
num2=8
a=num1+num2
b=num1/num2
c=num1%num2
print(f'20加8的结果是：{a}')
print(f'20除以8的结果是：{b}')
print(f'20对8求余的结果是：{c}')
# Out:
# 20加8的结果是：28
# 20除以8的结果是：2.5
# 20对8求余的结果是：4

# %%
price=19.9
discount=0.8
final_price=price*discount
saved_amount=price-final_price
print(f'最终的价格是：{final_price:.2f}')
print(f'节省的金额是：{saved_amount:.2f}')
# Out:
# 最终的价格是：15.92
# 节省的金额是：3.98
